# %%
import pandas as pd

# %%
data = pd.read_csv('./fortnite_data_project/fortnite_data.csv')

# %%
data.head()
# Out:
#   Game Type Group Members        Date   Time  Place  Total Players  \
# 0      duos         simba  2019-08-07  21:46      3             99
# 1      duos         simba  2019-08-07  21:15      2             99
# 2      duos         simba  2019-08-07  20:52     47             98
# 3      duos         simba  2019-08-07  20:47     11             96
# 4      duos         simba  2019-08-07  20:34     18            100
#
#    Eliminations  Assists  Revives  Accuracy (%)  Hits  Head Shots  \
# 0             1        0        0          0.10    22           2
# 1             0        9        0          0.29    51          20
# 2             0        1        0          0.44     7           0
# 3             2        0        0          0.55    26           0
# 4             0        2        0          0.12     3           0
#
#    Distance Traveled (in meters)  Materials Gathered  Materials Used  \
# 0                          938.0                 806             170
# ...

# %%
data.columns
# Out:
# Index(['Game Type', 'Group Members', 'Date', 'Time', 'Place', 'Total Players',
#        'Eliminations', 'Assists', 'Revives', 'Accuracy (%)', 'Hits',
#        'Head Shots', 'Distance Traveled (in meters)', 'Materials Gathered',
#        'Materials Used', 'Damage Taken', 'Damage To Players',
#        'Damage To Structures'],
#       dtype='object')

# %%
data.
