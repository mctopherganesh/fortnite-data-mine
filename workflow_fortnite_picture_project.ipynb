# %%
import pandas as pd

# %%
fortnite_data = pd.read_csv('fortnite_data.csv')
fortnite_data.head()
# Out:
#   Game Type Group Members        Date   Time  Place  Total Players  \
# 0      duos         simba  2019-08-07  21:46      3             99
# 1      duos         simba  2019-08-07  21:15      2             99
# 2      duos         simba  2019-08-07  20:52     47             98
# 3      duos         simba  2019-08-07  20:47     11             96
# 4      duos         simba  2019-08-07  20:34     18            100
#
#    Eliminations  Assists  Revives  Accuracy (%)  Hits  Head Shots  \
# 0             1        0        0          0.10    22           2
# 1             0        9        0          0.29    51          20
# 2             0        1        0          0.44     7           0
# 3             2        0        0          0.55    26           0
# 4             0        2        0          0.12     3           0
#
#    Distance Traveled (in meters)  Materials Gathered  Materials Used  \
# 0                          938.0                 806             170
# ...

# %%
sum(fortnite_data['Accuracy (%)']) / len(fortnite_data['Accuracy (%)'])
# Out:
# 0.20061224489795917

# %%
import matplotlib.pyplot as plt

# %%
x = fortnite_data['Place']
y = fortnite_data['Distance Traveled (in meters)']
plt.scatter(y,x)

# %%
fortnite_data['Damage To Players'] > 2000
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39     True
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# Name: Damage To Players, dtype: bool

# %%
fortnite_data
# Out:
#    Game Type               Group Members        Date   Time  Place  \
# 0       duos                       simba  2019-08-07  21:46      3
# 1       duos                       simba  2019-08-07  21:15      2
# 2       duos                       simba  2019-08-07  20:52     47
# 3       duos                       simba  2019-08-07  20:47     11
# 4       duos                       simba  2019-08-07  20:34     18
# 5       duos                       simba  2019-08-07  20:25     14
# 6      solos                        none  2019-08-07  16:33      3
# 7      solos                        none  2019-08-07  11:58     48
# 8      solos                        none  2019-08-07  11:53      8
# 9      solos                        none  2019-08-07  11:37     71
# 10     solos                        none  2019-08-07  11:33     59
# 11     solos                        none  2019-08-06  12:37      3
# 12     solos                        none  2019-08-06  12:14     19
# ...

# %%
bad_data_row = fortnite_data[fortnite_data['Damage To Players'] > 7000]

# %%
bad_data_row
# Out:
#    Game Type          Group Members        Date   Time  Place  Total Players  \
# 39     trios  simba, Wickid_Prodigy  2019-07-29  23:24      7             99
#
#     Eliminations  Assists  Revives  Accuracy (%)  Hits  Head Shots  \
# 39             0        1        0          0.01     1           0
#
#     Distance Traveled (in meters)  Materials Gathered  Materials Used  \
# 39                         4000.0                 760             275
#
#     Damage Taken  Damage To Players  Damage To Structures
# 39            35               9435                   NaN
